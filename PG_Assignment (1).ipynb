# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Grecia Soria**
# My current occupation is Validation Engineer.

# %% [markdown]
# _I am interested in Data Science because I work with lots of data
# on test equipment and product validation and I want to learn from that data._

# %% [markdown]
# ### My code below is a sum of 100 plus 3.

# %%
100 + 3
# Out:
# 103

# %% [markdown]
# <img src = "https://www.w3schools.com/html/pic_trulli.jpg" alt="Trulli" style="width:500px;height:250px;">
# >Above you can see a very cute set of three white houses that I found on the internet and next I'm sharing a link to an IBM video where Sonia Malik meets with Leon Katsnelson and Rav Ahuja, along with Coursera's Kevin McFarland to talk about IBM's Data Science Professional Certificate Program.
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=stgQeAd8mdI
# " target="_blank"><img src="http://img.youtube.com/vi/stgQeAd8mdI/0.jpg"
# width="240" height="180" border="10" /></a>
